# %%
import os
import openai
import pandas as pd
import numpy as np
import json
import time

# %%
# You need to set your OpenAI API key as an environment variable
# You can find your API key here: https://beta.openai.com/account/api-keys
# If you do not have an API key, you can sign up for free here: https://beta.openai.com/signup
OPENAI_API_KEY = os.environ["OPENAI_API_KEY"]
model_family = "babbage"
# You may also consider text-embedding-ada-002 for both query and doc models
doc_model_name = f"text-search-{model_family}-doc-001"
query_model_name = f"text-search-{model_family}-query-001"
datafile_path = "./dataset/tmdb_5000_movies.csv"
searchfile_path = f"./embeddings/tmdb_5000_movies_search_{model_family}.csv"

# %%
def get_embedding(text, model=doc_model_name):
   text = text.replace("\n", " ")
   return openai.Embedding.create(input = [text], model=model)["data"][0]["embedding"]

# %%
# read source data
df = pd.read_csv(datafile_path)

def combined_info(row):
    # join all columns into one string each starting with a new line
    # budget,genres,homepage,id,keywords,original_language,original_title,overview,popularity,production_companies,production_countries,release_date,revenue,runtime,spoken_languages,status,tagline,title,vote_average,vote_count
    # columns = ["budget", "genres", "homepage", "keywords", "original_language", "original_title", "overview", "popularity", "production_companies", "production_countries", "release_date", "revenue", "runtime", "spoken_languages", "status", "tagline", "title", "vote_average", "vote_count"]
    columns = ["title", "overview"]
    columns_to_join = [f"{column.capitalize()}: {row[column]}" for column in columns]
    return "\n".join(columns_to_join)

df["combined_info"] = df.apply(lambda row: combined_info(row), axis=1)
df[["id", "title", "combined_info"]]
# Out:
#           id                                     title  \
# 0      19995                                    Avatar
# 1        285  Pirates of the Caribbean: At World's End
# 2     206647                                   Spectre
# 3      49026                     The Dark Knight Rises
# 4      49529                               John Carter
# ...      ...                                       ...
# 4798    9367                               El Mariachi
# 4799   72766                                 Newlyweds
# 4800  231617                 Signed, Sealed, Delivered
# 4801  126186                          Shanghai Calling
# 4802   25975                         My Date with Drew
#
#                                           combined_info
# 0     Title: Avatar\nOverview: In the 22nd century, ...
# 1     Title: Pirates of the Caribbean: At World's En...
# 2     Title: Spectre\nOverview: A cryptic message fr...
# 3     Title: The Dark Knight Rises\nOverview: Follow...
# 4     Title: John Carter\nOverview: John Carter is a...
# ...                                                 ...
# 4798  Title: El Mariachi\nOverview: El Mariachi just...
# 4799  Title: Newlyweds\nOverview: A newlywed couple'...
# 4800  Title: Signed, Sealed, Delivered\nOverview: "S...
# 4801  Title: Shanghai Calling\nOverview: When ambiti...
# 4802  Title: My Date with Drew\nOverview: Ever since...
#
# [4803 rows x 3 columns]

# %%
# get combines_info column of the first row of df
df["combined_info"][0], len(get_embedding(df["combined_info"][0]))
# Out:
# ('Title: Avatar\nOverview: In the 22nd century, a paraplegic Marine is dispatched to the moon Pandora on a unique mission, but becomes torn between following orders and protecting an alien civilization.',
#  2048)

# %%
# run this only if you want to recompute the embeddings!
# TODO uncomment for embedding computation
# df["combined_info_search"] = df["combined_info"].apply(lambda x: get_embedding(x))
# df.to_csv(searchfile_path, index=False)

# %%
# start from here if you have already saved the embeddings
df = pd.read_csv(searchfile_path)
df["combined_info_search"] = df["combined_info_search"].apply(lambda x: json.loads(x))
df[["title", "combined_info_search"]]
# Out:
#                                          title  \
# 0                                       Avatar
# 1     Pirates of the Caribbean: At World's End
# 2                                      Spectre
# 3                        The Dark Knight Rises
# 4                                  John Carter
# ...                                        ...
# 4798                               El Mariachi
# 4799                                 Newlyweds
# 4800                 Signed, Sealed, Delivered
# 4801                          Shanghai Calling
# 4802                         My Date with Drew
#
#                                    combined_info_search
# 0     [-0.007991954684257507, 0.012535694986581802, ...
# 1     [-0.016552643850445747, 0.0188571996986866, -0...
# 2     [0.0037659681402146816, 0.03368673846125603, 0...
# 3     [-0.034091781824827194, 0.03374126926064491, 0...
# 4     [-0.01051109004765749, 0.018903380259871483, -...
# ...                                                 ...
# 4798  [-0.021842991933226585, 0.013724438846111298, ...
# 4799  [-0.007133991923183203, 0.02944451943039894, -...
# 4800  [-0.0048161824233829975, 0.06203579157590866, ...
# 4801  [-0.011022549122571945, 0.019958987832069397, ...
# 4802  [-0.010364260524511337, 0.02809353545308113, -...
#
# [4803 rows x 2 columns]

# %%
# collect durations of 100 queries
durations = []
for i in range(100):
    prev = time.time()
    get_embedding(
        text=df["title"][i],
        model=query_model_name
    )
    durations.append(time.time() - prev)
    # print(f"Query {i} took {durations[-1]} seconds")
print('average duration:', np.mean(durations))
print('median duration:', np.median(durations))
print('max duration:', np.max(durations))
print('min duration:', np.min(durations))
# Out:
# average duration: 0.22487717151641845
# median duration: 0.2076643705368042
# max duration: 1.3016021251678467
# min duration: 0.17632818222045898

# %%
from openai.embeddings_utils import cosine_similarity

def search_movies(df, query, n=3, pprint=True):
    embedding = get_embedding(
        query,
        model=query_model_name
    )
    prev = time.time()
    df["similarities"] = df.combined_info_search.apply(lambda x: cosine_similarity(x, embedding))
    print(f"Cosine similarity calculation for {df.size} records of {len(df["combined_info_search"][0])} dimentions took {time.time() - prev} seconds")

    res = (
        df.sort_values("similarities", ascending=False)
        .head(n)
        .combined_info
    )
    if pprint:
        for r in res:
            print(r)
            print()
    return df, res

# %%
df, res = search_movies(df, "movie about the wizardry school", n=1)
df.sort_values("similarities", ascending=False)[["title", "similarities"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/homebrew/lib/python3.10/site-packages/pandas/core/indexes/base.py:3800, in Index.get_loc(self, key, method, tolerance)
#    3799 try:
# -> 3800     return self._engine.get_loc(casted_key)
#    3801 except KeyError as err:
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 df, res = search_movies(df, "movie about the wizardry school", n=1)
#       2 df.sort_values("similarities", ascending=False)[["title", "similarities"]]
#
# Cell In[30], line 10, in search_movies(df, query, n, pprint)
#       8 prev = time.time()
#       9 df["similarities"] = df.combined_info_search.apply(lambda x: cosine_similarity(x, embedding))
# ---> 10 print(f"Cosine similarity calculation for {len(df)} records of {len(df[0])} dimentions took {time.time() - prev} seconds")
#      12 res = (
#      13     df.sort_values("similarities", ascending=False)
#      14     .head(n)
#      15     .combined_info
#      16 )
#      17 if pprint:
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/core/frame.py:3805, in DataFrame.__getitem__(self, key)
#    3803 if self.columns.nlevels > 1:
#    3804     return self._getitem_multilevel(key)
# -> 3805 indexer = self.columns.get_loc(key)
#    3806 if is_integer(indexer):
#    3807     indexer = [indexer]
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3800     return self._engine.get_loc(casted_key)
#    3801 except KeyError as err:
# -> 3802     raise KeyError(key) from err
#    3803 except TypeError:
#    3804     # If we have a listlike key, _check_indexing_error will raise
#    3805     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3806     #  the TypeError.
#    3807     self._check_indexing_error(key)
#
# KeyError: 0
